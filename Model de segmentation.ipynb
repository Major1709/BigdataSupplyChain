# %%
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.clustering import KMeans
from pyspark.ml import PipelineModel
from pyspark.ml.evaluation import ClusteringEvaluator
from pyspark.sql.functions import (
    col, sum, avg, countDistinct, count, max, datediff, lit
)
from pyspark.ml import PipelineModel
from pipeline_segm.SegmentationClass import SegmentationClass

# %%
# Démarrer une session Spark
spark = SparkSession.builder.appName("Modelseg").getOrCreate()

# Lire le CSV depuis HDFS ou local
df = spark.read.option("header", "true").csv("hdfs://localhost:9000/projet/gold/train_df")
# Out:
# 25/06/02 02:17:53 WARN Utils: Your hostname, toma-Nitro-AN517-52 resolves to a loopback address: 127.0.1.1; using 192.168.88.11 instead (on interface enp7s0)
# 25/06/02 02:17:53 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/02 02:17:55 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
loaded_pipeline_model = PipelineModel.load("/home/toma/Documents/BIGDATA/big_data_pipeline_v3")
df = loaded_pipeline_model.transform(df)

# %%
geo_assembler = VectorAssembler(inputCols=["x", "y", "z"], outputCol="features")

# %%
seg = SegmentationClass()



kmeans = KMeans(featuresCol="features", predictionCol="cluster", k=15, seed=42)

pipeline = Pipeline(stages=[seg, geo_assembler, kmeans])

model = pipeline.fit(df)

clustered = model.transform(df)
model.write().overwrite().save("/home/toma/Documents/BIGDATA/segmentation_model")

# %%
clustered = clustered.select(
        "customer_id", "order_id", "customer_city",
        "product_name","order_item_quantity","product_price","shipping_mode","cluster"
    )
clustered.show(5)
# Out:
# [Stage 1168:===================================>                    (5 + 3) / 8]
# +-----------+--------+-------------+--------------------+-------------------+-------------+--------------+-------+
# |customer_id|order_id|customer_city|        product_name|order_item_quantity|product_price| shipping_mode|cluster|
# +-----------+--------+-------------+--------------------+-------------------+-------------+--------------+-------+
# |      10000|   68882|       Caguas|Nike Men's Dri-FI...|                  1|         50.0|Standard Class|      1|
# |      10009|   15502|       Caguas|Diamondback Women...|                  1|   299.980011|Standard Class|      1|
# |      10010|    8757|      Phoenix|Perfect Fitness P...|                  5|  59.99000168|   First Class|     12|
# |      10012|   36469|     Lynnwood|Perfect Fitness P...|                  4|  59.99000168|Standard Class|     11|
# |      10038|   27853|       Caguas|Nike Men's Free 5...|                  3|  99.98999786|Standard Class|      1|
# +-----------+--------+-------------+--------------------+-------------------+-------------+--------------+-------+
# only showing top 5 rows

# %%
seg = SegmentationClass()

assembler = VectorAssembler(
    inputCols=[
        "total_sales", "total_orders", "avg_order_value", "total_quantity",
        "avg_discount_rate", "num_categories", "frequency",
        "avg_shipping_delay", "late_delivery_rate", "avg_product_price",
        "recency_days"
    ],
    outputCol="features"
)

kmeans = KMeans(featuresCol="features", predictionCol="cluster", k=2, seed=42)

pipeline = Pipeline(stages=[seg, assembler, kmeans])

model = pipeline.fit(df)

clusters_df = model.transform(df)
model.write().overwrite().save("/home/toma/Documents/BIGDATA/segmentation_model")

# %%
clusters_df.show(10)
# Out:
# [Stage 133:===============================================>         (5 + 1) / 6]
# +-----------+------------------+------------+------------------+--------------+-------------------+--------------+-------------------+---------+------------------+------------------+------------------+------------+--------------------+-------+
# |customer_id|       total_sales|total_orders|   avg_order_value|total_quantity|  avg_discount_rate|num_categories|    last_order_date|frequency|avg_shipping_delay|late_delivery_rate| avg_product_price|recency_days|            features|cluster|
# +-----------+------------------+------------+------------------+--------------+-------------------+--------------+-------------------+---------+------------------+------------------+------------------+------------+--------------------+-------+
# |       5645|     2889.22006228|           5|     577.844012456|            24|0.09083333166666667|             7|2017-03-16 00:48:00|       12|3.4166666666666665|0.5833333333333334|203.32000510499998|         322|[2889.22006228,5....|      1|
# |       4937|      2449.5200329|           5|      489.90400658|            24|0.10769230846153845|             7|2017-05-18 19:06:00|       13|3.6923076923076925|0.6923076923076923|154.21769582692306|         259|[2449.5200329,5.0...|      1|
# |       6240|2010.8100319200003|           6|335.13500532000006|            20| 0.0661538466923077|             8|2017-04-30 01:36:00|       13| 3.923076923076923|0.6923076923076923|147.06538905153846|         277|[2010.81003192000...|      1|
# |      10351|      3589.2500496|           6| 598.2083415999999|            48|0.08111111172222223|             9|2017-10-01 09:27:00|       18| 3.111111111111111|0.8888888888888888|118.32111401333333|         123|[3589.2500496,6.0...|      1|
# |       9583|     2323.38002404|           4|      580.84500601|            27|0.09384615369230771|             5|2016-02-26 23:24:00|       13| 4.384615384615385|0.6923076923076923|137.68231172307694|         706|[2323.38002404,4....|      1|
# |      11888|     4197.21002962|          11| 381.5645481472727|            61|0.10142857133333334|            12|2017-07-04 19:54:00|       21| 3.761904761904762|0.6190476190476191|120.94143132095236|         212|[4197.21002962,11...|      1|
# |      18947|       258.0400085|           1|       258.0400085|             1|               0.01|             1|2018-01-05 13:31:00|        1|               5.0|               1.0|       260.6499939|          27|[258.0400085,1.0,...|      0|
# |      10096|     1051.17000588|           7|150.16714369714285|            20|      0.16375000075|             7|2017-09-26 08:14:00|        8|             3.125|               0.5|101.73875260624999|         128|[1051.17000588,7....|      0|
# |       9993|     2635.29999918|           7|376.47142845428573|            40|0.10333333366666667|             8|2017-06-03 18:22:00|       15| 3.933333333333333|0.6666666666666666|115.98667017999999|         243|[2635.29999918,7....|      1|
# |      11078|             374.0|           2|             187.0|             6|0.12666666633333334|             3|2017-09-29 20:19:00|        3|3.3333333333333335|               1.0| 79.99333572666667|         125|[374.0,2.0,187.0,...|      0|
# +-----------+------------------+------------+------------------+--------------+-------------------+--------------+-------------------+---------+------------------+------------------+------------------+------------+--------------------+-------+
# only showing top 10 rows

# %%
from datetime import timedelta

# Récupérer la date max
max_date_row = df.select(max("order_date_(dateorders)")).collect()[0]
max_date = max_date_row[0]

if max_date is None:
    raise ValueError("Aucune date valide trouvée dans 'order_date'.")

# ✅ Corriger ici avec timedelta
today = max_date + timedelta(days=1)  # ou ajouter timedelta(1) en Pandas

# Agrégation par client
features_df = df.groupBy("customer_id").agg(
    sum("order_item_total").alias("total_sales"),
    countDistinct("order_id").alias("total_orders"),
    (sum("order_item_total") / countDistinct("order_id")).alias("avg_order_value"),
    sum("order_item_quantity").alias("total_quantity"),
    avg("order_item_discount_rate").alias("avg_discount_rate"),
    countDistinct("category_id").alias("num_categories"),
    max("order_date_(dateorders)").alias("last_order_date"),
    count("order_id").alias("frequency"),
    avg("days_for_shipping_(real)").alias("avg_shipping_delay"),
    avg("late_delivery_risk").alias("late_delivery_rate"),
    avg("order_item_product_price").alias("avg_product_price")
)

# Calcul de la récence (en jours)
features_df = features_df.withColumn("recency_days", datediff(lit(today), col("last_order_date")))

# Ajouter le segment client (optionnel)
segments_df = df.select("customer_id", "customer_segment").dropDuplicates(["customer_id"])
features_df = features_df.join(segments_df, on="customer_id", how="left")

# Afficher un aperçu
features_df.show(10)
# Out:
# +-----------+------------------+------------+------------------+--------------+-------------------+--------------+-------------------+---------+------------------+------------------+------------------+------------+----------------+
# |customer_id|       total_sales|total_orders|   avg_order_value|total_quantity|  avg_discount_rate|num_categories|    last_order_date|frequency|avg_shipping_delay|late_delivery_rate| avg_product_price|recency_days|customer_segment|
# +-----------+------------------+------------+------------------+--------------+-------------------+--------------+-------------------+---------+------------------+------------------+------------------+------------+----------------+
# |        467|     3732.31005469|           7|      533.18715067|            40|0.11900000025000002|             9|2017-03-20 19:21:00|       20|               2.6|               0.6|    147.7365033185|         318|        Consumer|
# |       7711|      1223.9600219|           4|     305.990005475|            17|0.09142857299999999|             5|2016-05-28 01:12:00|        7|3.7142857142857144|0.7142857142857143| 105.9928586157143|         614|        Consumer|
# |      18947|       258.0400085|           1|       258.0400085|             1|               0.01|             1|2018-01-05 13:31:00|        1|               5.0|               1.0|       260.6499939|          27|       Corporate|
# |       3414|     1647.00002304|           4|      411.75000576|            19| 0.1266666671111111|             4|2016-01-13 17:09:00|        9| 4.888888888888889|0.8888888888888888|154.98778258999997|         750|     Home Office|
# |       8433|1330.2000274499999|           2| 665.1000137249999|            18|0.08428571471428571|             6|2016-01-02 09:17:00|        7| 4.571428571428571|               1.0|135.70143264142857|         761|        Consumer|
# |      11332|     2710.54004662|           6|451.75667443666663|            40|0.09350000085000001|            10|2017-05-28 06:07:00|       20|              3.75|               0.3|    104.0910025625|         249|     Home Office|
# |       5645|     3036.59006125|           5|      607.31801225|            28|0.10142857092857145|             8|2017-03-16 00:48:00|       14|3.4285714285714284|0.6428571428571429|184.63000475214287|         322|        Consumer|
# |      18726|       463.3399963|           1|       463.3399963|             1|        0.129999995|             1|2018-01-02 08:06:00|        1|               0.0|               0.0|       532.5800171|          30|        Consumer|
# |       2136|        369.199997|           1|        369.199997|             6|0.04999999966666666|             2|2016-01-12 23:17:00|        3|               6.0|               1.0| 97.32333692333333|         751|        Consumer|
# |       7273|     2566.86003486|           6|427.81000580999995|            34|    0.1068750000625|             8|2017-06-18 15:44:00|       16|             3.875|            0.6875|124.05000269687497|         228|        Consumer|
# +-----------+------------------+------------+------------------+--------------+-------------------+--------------+-------------------+---------+------------------+------------------+------------------+------------+----------------+
# only showing top 10 rows

# %%
from pyspark.sql.functions import radians, cos, sin

dataset = df.withColumn("lat_rad", radians("latitude"))
dataset = dataset.withColumn("lon_rad", radians("longitude"))

dataset = dataset.withColumn("x", cos("lat_rad") * cos("lon_rad")) \
                    .withColumn("y", cos("lat_rad") * sin("lon_rad")) \
                    .withColumn("z", sin("lat_rad"))
dataset = dataset.dropDuplicates(["customer_id"])
# Assembler les features dans une colonne vectorielle

features_vector_df = geo_assembler.transform(dataset)

# Initialiser l’évaluateur silhouette
evaluator = ClusteringEvaluator(featuresCol='features', metricName='silhouette', distanceMeasure='squaredEuclidean')

# %%
# Boucle pour tester k=2 à 5
for k in range(15, 16):
    kmeans = KMeans(featuresCol="features",k=k, seed=42)
    model = kmeans.fit(features_vector_df)
    predictions = model.transform(features_vector_df)
    score = evaluator.evaluate(predictions)
    print(f"Silhouette Score pour k={k} : {score:.4f}")
# Out:
# Silhouette Score pour k=15 : 0.8410

# %%
model.write().overwrite().save("/home/toma/Documents/BIGDATA/segmentation_model")

# %%
# Lire le CSV depuis HDFS ou local
dfs = spark.read.option("header", "true").csv("hdfs://localhost:9000/projet/gold/test_df")
pipeline_model = PipelineModel.load("/home/toma/Documents/BIGDATA/big_data_pipeline_v3")
pipeline_seg = PipelineModel.load("/home/toma/Documents/BIGDATA/segmentation_model")
dfs = pipeline_model.transform(dfs)
dfs = pipeline_seg.transform(dfs)
dfs.show()
# Out:
# [Stage 1184:==============>                                         (2 + 6) / 8]
# +--------+------------------------+-----------------------------+-----------------+------------------+-----------------+------------------+-----------+--------------------+-----------------+----------------+--------------+--------------+-----------+--------------+-----------------+----------------+--------------+--------------------+----------------+-------------+---------------+-----------+------------+------+-------------------+--------------+-----------------+-----------------------+--------+----------------------+-------------------+------------------------+-------------+------------------------+-----------------------+-------------------+-----------+----------------+----------------------+---------------+--------------------+---------------+-------------+---------------+-------------------+-------------------+--------------------+--------------------+-------------+--------------+--------------------------+--------------+-------------------+-------------------+--------------------+-------------------+-------------------+--------------------+-------+
# |    type|days_for_shipping_(real)|days_for_shipment_(scheduled)|benefit_per_order|sales_per_customer|  delivery_status|late_delivery_risk|category_id|       category_name|    customer_city|customer_country|customer_email|customer_fname|customer_id|customer_lname|customer_password|customer_segment|customer_state|     customer_street|customer_zipcode|department_id|department_name|   latitude|   longitude|market|         order_city| order_country|order_customer_id|order_date_(dateorders)|order_id|order_item_cardprod_id|order_item_discount|order_item_discount_rate|order_item_id|order_item_product_price|order_item_profit_ratio|order_item_quantity|      sales|order_item_total|order_profit_per_order|   order_region|         order_state|   order_status|order_zipcode|product_card_id|product_category_id|product_description|       product_image|        product_name|product_price|product_status|shipping_date_(dateorders)| shipping_mode|            lat_rad|            lon_rad|                   x|                  y|                  z|            features|cluster|
# +--------+------------------------+-----------------------------+-----------------+------------------+-----------------+------------------+-----------+--------------------+-----------------+----------------+--------------+--------------+-----------+--------------+-----------------+----------------+--------------+--------------------+----------------+-------------+---------------+-----------+------------+------+-------------------+--------------+-----------------+-----------------------+--------+----------------------+-------------------+------------------------+-------------+------------------------+-----------------------+-------------------+-----------+----------------+----------------------+---------------+--------------------+---------------+-------------+---------------+-------------------+-------------------+--------------------+--------------------+-------------+--------------+--------------------------+--------------+-------------------+-------------------+--------------------+-------------------+-------------------+--------------------+-------+
# | PAYMENT|                       3|                            4|      15.47999954|       175.9600067| Advance shipping|                 0|         29|       Shop By Sport|          Phoenix|         EE. UU.|     XXXXXXXXX|       Patrick|      10010|          Diaz|        XXXXXXXXX|       Corporate|            AZ|     1400 Silent Run|           85033|            5|           Golf| 33.4926796|-112.2088623| LATAM|         Cuernavaca|        M�xico|            10010|    2017-03-17 05:52:00|   55232|                   627|        23.98999977|             0.119999997|       138135|             39.99000168|            0.090000004|                  5|199.9499969|     175.9600067|           15.47999954|Central America|             Morelos|PENDING_PAYMENT|         NULL|            627|                 29|               NULL|http://images.acm...|Under Armour Girl...|  39.99000168|             0|       2017-03-20 05:52:00|Standard Class| 0.5845575343355375|-1.9584140970519375|-0.31522214456004105|-0.7720868900730438|  0.551830439316557|[-0.3152221445600...|     12|
# |   DEBIT|                       2|                            4|            107.0|       260.9700012| Advance shipping|                 0|          9|    Cardio Equipment|         Lynnwood|         EE. UU.|     XXXXXXXXX|        Robert|      10012|       Montoya|        XXXXXXXXX|        Consumer|            WA|      3282 Lost Gate|           98037|            3|       Footwear|47.84322357|-122.2460785| LATAM|       Buenos Aires|     Argentina|            10012|    2015-04-18 12:17:00|    7366|                   191|               39.0|             0.129999995|        18446|             99.98999786|            0.409999996|                  3|299.9700012|     260.9700012|                 107.0|  South America|        Buenos Aires|       COMPLETE|         NULL|            191|                  9|               NULL|http://images.acm...|Nike Men's Free 5...|  99.98999786|             0|       2015-04-20 12:17:00|Standard Class| 0.8350217760642558| -2.133596567476451| -0.3581026897549607|-0.5676444982019159| 0.7413111271600862|[-0.3581026897549...|     11|
# |   DEBIT|                       6|                            4|     -587.9699707|        335.980011|    Late delivery|                 1|         45|             Fishing|           Caguas|     Puerto Rico|     XXXXXXXXX|         Julie|      10038|         Smith|        XXXXXXXXX|       Corporate|            PR|7441 Cozy Autumn ...|             725|            7|       Fan Shop|18.25424767|-66.37056732|Europe|          Edinburgh|   Reino Unido|            10038|    2017-09-10 06:51:00|   67360|                  1004|               64.0|             0.159999996|       168358|              399.980011|                  -1.75|                  1| 399.980011|      335.980011|          -587.9699707|Northern Europe|             Escocia|       COMPLETE|         NULL|           1004|                 45|               NULL|http://images.acm...|Field & Stream Sp...|   399.980011|             0|       2017-09-16 06:51:00|Standard Class|0.31859672431600333| -1.158384926150549| 0.38064882413508117|-0.8700521828580278| 0.3132342123532504|[0.38064882413508...|      1|
# |TRANSFER|                       6|                            2|      39.97999954|       118.2900009|    Late delivery|                 1|         18|      Men's Footwear|           Conway|         EE. UU.|     XXXXXXXXX|          Mary|      10039|        Butler|        XXXXXXXXX|        Consumer|            AR|     7786 Quiet Mall|           72032|            4|        Apparel|35.09189606|-92.43454742| LATAM|Consolaci�n del Sur|          Cuba|            10039|    2015-02-13 23:56:00|    3015|                   403|        11.69999981|             0.090000004|         7519|             129.9900055|            0.340000004|                  1|129.9900055|     118.2900009|           39.97999954|      Caribbean|       Pinar del R�o|     PROCESSING|         NULL|            403|                 18|               NULL|http://images.acm...|Nike Men's CJ Eli...|  129.9900055|             0|       2015-02-19 23:56:00|  Second Class| 0.6124691270146256|-1.6132871950698298|-0.03475688628553...|-0.8174925019751705| 0.5748895268398184|[-0.0347568862855...|      3|
# |   DEBIT|                       4|                            4|      36.38999939|       72.77999878| Shipping on time|                 0|         29|       Shop By Sport|             Troy|         EE. UU.|     XXXXXXXXX|          Mary|      10052|       Aguilar|        XXXXXXXXX|        Consumer|            MI|3891 Red Pony Cro...|           48098|            5|           Golf| 42.5804596|-83.15601349|Europe|      Bry-sur-Marne|       Francia|            10052|    2015-09-11 05:25:00|   17348|                   627|        7.199999809|             0.090000004|        43359|             39.99000168|                    0.5|                  2|79.98000336|     72.77999878|           36.38999939| Western Europe|     Isla de Francia|        ON_HOLD|         NULL|            627|                 29|               NULL|http://images.acm...|Under Armour Girl...|  39.99000168|             0|       2015-09-15 05:25:00|Standard Class| 0.7431692170324277| -1.451346228233321| 0.08774542764837902|-0.7310810488999635| 0.6766248885949527|[0.08774542764837...|     13|
# |TRANSFER|                       2|                            1|             -6.0|       47.99000168|    Late delivery|                 1|         17|              Cleats|    Mechanicsburg|         EE. UU.|     XXXXXXXXX|     Elizabeth|      10058|       Proctor|        XXXXXXXXX|       Corporate|            PA|   6178 Tawny Villas|           17055|            4|        Apparel|40.21145248| -77.0072937|  USCA|        Los Angeles|Estados Unidos|            10058|    2016-05-06 04:23:00|   33649|                   365|               12.0|             0.200000003|        83988|             59.99000168|           -0.129999995|                  1|59.99000168|     47.99000168|                  -6.0|    West of USA|          California|        PENDING|        90032|            365|                 17|               NULL|http://images.acm...|Perfect Fitness P...|  59.99000168|             0|       2016-05-08 04:23:00|   First Class| 0.7018222427852393|-1.3440308231152867| 0.17169297224686755|-0.7441161237728504| 0.6456103450397185|[0.17169297224686...|      0|
# |TRANSFER|                       3|                            4|     -38.45999908|       167.9299927| Advance shipping|                 0|         46|Indoor/Outdoor Games|       Carmichael|         EE. UU.|     XXXXXXXXX|          Mary|      10068|         Gates|        XXXXXXXXX|       Corporate|            CA|4571 Rustic Highl...|           95608|            7|       Fan Shop|38.63631058|-121.3210526|Africa|         Alexandria|        Egipto|            10068|    2016-10-01 18:12:00|   43827|                  1014|        31.98999977|             0.159999996|       109466|             49.97999954|           -0.230000004|                  4|199.9199982|     167.9299927|          -38.45999908|   North Africa|          Alejandr�a|     PROCESSING|         NULL|           1014|                 46|               NULL|http://images.acm...|O'Brien Men's Neo...|  49.97999954|             0|       2016-10-04 18:12:00|Standard Class|   0.67433083044412|-2.1174518198552272|-0.40605454889607656|-0.6672899467022564| 0.6243747515322058|[-0.4060545488960...|      2|
# |TRANSFER|                       6|                            4|      19.90999985|       41.47999954|    Late delivery|                 1|         46|Indoor/Outdoor Games|       Sacramento|         EE. UU.|     XXXXXXXXX|          Mary|       1008|         Smith|        XXXXXXXXX|     Home Office|            CA|6473 Bright Expre...|           95828|            7|       Fan Shop|37.78511429|-122.2878037|Europe|               Graz|       Austria|             1008|    2017-07-13 09:13:00|   63325|                  1014|                8.5|             0.170000002|       158328|             49.97999954|            0.479999989|                  1|49.97999954|     41.47999954|           19.90999985| Western Europe|              Stiria|        PENDING|         NULL|           1014|                 46|               NULL|http://images.acm...|O'Brien Men's Neo...|  49.97999954|             0|       2017-07-19 09:13:00|Standard Class| 0.6594746526028595| -2.134324809597504| -0.4221640526201319|-0.6681123272851698| 0.6127017470229221|[-0.4221640526201...|      2|
# |TRANSFER|                       6|                            4|      135.2899933|       287.8599854|    Late delivery|                 1|         38|    Kids' Golf Clubs|       Grove City|         EE. UU.|     XXXXXXXXX|          Emma|      10088|       Osborne|        XXXXXXXXX|       Corporate|            OH|  5423 Heather Falls|           43123|            6|       Outdoors|39.85160065|-83.06317139|Europe|             Toulon|       Francia|            10088|    2017-09-09 09:50:00|   67300|                   295|        11.98999977|             0.039999999|       168196|             99.94999695|            0.469999999|                  3|299.8500061|     287.8599854|           135.2899933| Western Europe|Provenza-Alpes-Co...|     PROCESSING|         NULL|            295|                 38|               NULL|http://images.acm...|Fitbit The One Wi...|  99.94999695|             0|       2017-09-15 09:50:00|Standard Class| 0.6955416435324124|-1.4497258279038547| 0.09271973333398431|-0.7620870501812101|   0.64080135689352|[0.09271973333398...|     13|
# |TRANSFER|                       2|                            4|      95.04000092|        395.980011| Advance shipping|                 0|         45|             Fishing|           Caguas|     Puerto Rico|     XXXXXXXXX|         Laura|      10096|          Case|        XXXXXXXXX|       Corporate|            PR|7004 Hazy Lake To...|             725|            7|       Fan Shop|18.26978493|-66.37052918|Europe|           Pozzuoli|        Italia|            10096|    2015-06-09 16:46:00|   10941|                  1004|                4.0|                    0.01|        27392|              399.980011|            0.239999995|                  1| 399.980011|      395.980011|           95.04000092|Southern Europe|            Campania|        PENDING|         NULL|           1004|                 45|               NULL|http://images.acm...|Field & Stream Sp...|   399.980011|             0|       2015-06-11 16:46:00|Standard Class|0.31886790065974174|-1.1583842604819723|  0.3806153429430074|-0.8699740775685828|0.31349173047318213|[0.38061534294300...|      1|
# |TRANSFER|                       2|                            1|     -4.199999809|       83.97000122|Shipping canceled|                 0|         46|Indoor/Outdoor Games|Dorchester Center|         EE. UU.|     XXXXXXXXX|          Mary|        101|        Briggs|        XXXXXXXXX|       Corporate|            MA|  8342 Crystal Drive|            2124|            7|       Fan Shop|37.68590927|-120.9584427|  USCA|         Burlington|Estados Unidos|              101|    2016-06-14 18:52:00|   36362|                  1014|        15.98999977|             0.159999996|        90791|             49.97999954|           -0.050000001|                  2|99.95999908|     83.97000122|          -4.199999809|  South of  USA|  Carolina del Norte|       CANCELED|        27217|           1014|                 46|               NULL|http://images.acm...|O'Brien Men's Neo...|  49.97999954|             0|       2016-06-16 18:52:00|   First Class| 0.6577431983693528|   -2.1111230831999| -0.4070955758513524|-0.6786352808021302| 0.6113324363820963|[-0.4070955758513...|      2|
# |TRANSFER|                       2|                            2|      17.28000069|       172.7700043| Shipping on time|                 0|         17|              Cleats|           Caguas|     Puerto Rico|     XXXXXXXXX|          Mary|      10104|          Chen|        XXXXXXXXX|       Corporate|            PR|       905 Blue Cape|             725|            4|        Apparel|18.24228668|-66.37056732| LATAM|             Toluca|        M�xico|            10104|    2015-01-07 13:39:00|     451|                   365|        7.199999809|             0.039999999|         1106|             59.99000168|            0.100000001|                  3|179.9700012|     172.7700043|           17.28000069|Central America|              M�xico|        PENDING|         NULL|            365|                 17|               NULL|http://images.acm...|Perfect Fitness P...|  59.99000168|             0|       2015-01-09 13:39:00|  Second Class| 0.3183879656587052| -1.158384926150549|   0.380675025583256|-0.8701120717260162| 0.3130359524620892|[0.38067502558325...|      1|
# |   DEBIT|                       2|                            4|      100.8700027|        387.980011| Advance shipping|                 0|         45|             Fishing|        San Pablo|         EE. UU.|     XXXXXXXXX|       Beverly|      10110|         Smith|        XXXXXXXXX|     Home Office|            CA|    2580 Dewy Circle|           94806|            7|       Fan Shop|37.95553589|-122.3302536|Europe|             Madrid|        Espa�a|            10110|    2017-08-12 23:32:00|   65421|                  1004|               12.0|             0.029999999|       163499|              399.980011|             0.25999999|                  1| 399.980011|      387.980011|           100.8700027|Southern Europe|              Madrid|       COMPLETE|         NULL|           1004|                 45|               NULL|http://images.acm...|Field & Stream Sp...|   399.980011|             0|       2017-08-14 23:32:00|Standard Class| 0.6624490706393763|-2.1350657001196467| -0.4216824329663775|-0.6662564977472584| 0.6150497580985738|[-0.4216824329663...|      2|
# |   DEBIT|                       2|                            4|     -28.18000031|       103.9899979| Advance shipping|                 0|         18|      Men's Footwear|      Los Angeles|         EE. UU.|     XXXXXXXXX|       Gregory|      10114|         Smith|        XXXXXXXXX|        Consumer|            CA|  1055 Crystal Woods|           90027|            4|        Apparel|34.03905487|-118.2566757|  USCA|      San Francisco|Estados Unidos|            10114|    2016-08-17 10:01:00|   40721|                   403|               26.0|             0.200000003|       101590|             129.9900055|           -0.270000011|                  1|129.9900055|     103.9899979|          -28.18000031|    West of USA|          California|        ON_HOLD|        94122|            403|                 18|               NULL|http://images.acm...|Nike Men's CJ Eli...|  129.9900055|             0|       2016-08-19 10:01:00|Standard Class| 0.5940935817485105|-2.0639683534281703|-0.39230433000232523|-0.7299098804327562| 0.5597578754319283|[-0.3923043300023...|     12|
# |TRANSFER|                       4|                            4|      71.97000122|       149.9400024| Shipping on time|                 0|         46|Indoor/Outdoor Games|    Silver Spring|         EE. UU.|     XXXXXXXXX|          Mark|       1012|         Watts|        XXXXXXXXX|       Corporate|            MD| 2210 Merry Leaf Row|           20906|            7|       Fan Shop|39.10291672|-77.07506561|  USCA|            Seattle|Estados Unidos|             1012|    2016-05-19 05:36:00|   34543|                  1014|                0.0|                     0.0|        86284|             49.97999954|            0.479999989|                  3|149.9400024|     149.9400024|           71.97000122|    West of USA|          Washington|        PENDING|        98103|           1014|                 46|               NULL|http://images.acm...|O'Brien Men's Neo...|  49.97999954|             0|       2016-05-23 05:36:00|Standard Class| 0.6824746438971416|-1.3452136660851517| 0.17357445428765664|-0.7563531606510894| 0.6307153123175697|[0.17357445428765...|      0|
# |   DEBIT|                       3|                            2|      174.8300018|        371.980011|    Late delivery|                 1|         45|             Fishing|         Brooklyn|         EE. UU.|     XXXXXXXXX|          Mary|      10124|        Santos|        XXXXXXXXX|     Home Office|            NY|1790 Noble Brook Run|           11229|            7|       Fan Shop| 40.6292305|-73.94178009|  USCA|          San Diego|Estados Unidos|            10124|    2016-08-13 15:17:00|   40462|                  1004|               28.0|                    0.07|       100971|              399.980011|            0.469999999|                  1| 399.980011|      371.980011|           174.8300018|    West of USA|          California|       COMPLETE|        92037|           1004|                 45|               NULL|http://images.acm...|Field & Stream Sp...|   399.980011|             0|       2016-08-16 15:17:00|  Second Class| 0.7091138447767019| -1.290527517356089| 0.20993319331828733| -0.729326243732095| 0.6511614888388435|[0.20993319331828...|      7|
# |    CASH|                       2|                            1|      9.880000114|       37.99000168|    Late delivery|                 1|         29|       Shop By Sport|          Buffalo|         EE. UU.|     XXXXXXXXX|     Alexander|      10133|         Smith|        XXXXXXXXX|     Home Office|            NY|  2797 Wishing Vista|           14221|            5|           Golf|42.95614243|-78.67983246|  USCA|            Seattle|Estados Unidos|            10133|    2016-07-14 19:32:00|   38419|                   627|                2.0|             0.050000001|        95891|             39.99000168|             0.25999999|                  1|39.99000168|     37.99000168|           9.880000114|    West of USA|          Washington|         CLOSED|        98105|            627|                 29|               NULL|http://images.acm...|Under Armour Girl...|  39.99000168|             0|       2016-07-16 19:32:00|   First Class| 0.7497261193591378|-1.3732221313445097|  0.1436607980376092|-0.7176373493537909| 0.6814383390444527|[0.14366079803760...|     13|
# |TRANSFER|                       4|                            4|      23.64999962|       90.95999908| Shipping on time|                 0|         46|Indoor/Outdoor Games|         Brighton|         EE. UU.|     XXXXXXXXX|         Louis|      10138|       Kennedy|        XXXXXXXXX|       Corporate|            MA|8981 Harvest Hill...|            2135|            7|       Fan Shop|42.34962845|-71.15328217|  USCA|           Paterson|Estados Unidos|            10138|    2016-04-30 13:09:00|   33263|                  1014|                9.0|             0.090000004|        83102|             49.97999954|             0.25999999|                  2|99.95999908|     90.95999908|           23.64999962|    East of USA|        Nueva Jersey|        PENDING|         7501|           1014|                 46|               NULL|http://images.acm...|O'Brien Men's Neo...|  49.97999954|             0|       2016-05-04 13:09:00|Standard Class| 0.7391404534487628|-1.2418590474670756| 0.23874015106266316|-0.6994246857499785| 0.6736529145146783|[0.23874015106266...|      7|
# |    CASH|                       3|                            4|      59.43000031|       204.9199982| Advance shipping|                 0|         46|Indoor/Outdoor Games|          Chicago|         EE. UU.|     XXXXXXXXX|          Mary|      10145|        Lester|        XXXXXXXXX|        Consumer|            IL|  5630 Tawny Circuit|           60644|            7|       Fan Shop|41.89487457|-87.76678467|  USCA|      New York City|Estados Unidos|            10145|    2016-07-16 11:07:00|   38532|                  1014|        44.97999954|             0.180000007|        96164|             49.97999954|            0.289999992|                  5|249.8999939|     204.9199982|           59.43000031|    East of USA|          Nueva York|         CLOSED|        10011|           1014|                 46|               NULL|http://images.acm...|O'Brien Men's Neo...|  49.97999954|             0|       2016-07-19 11:07:00|Standard Class| 0.7312035009565435| -1.531819366380385| 0.02900598446106004|-0.7438059305044702|  0.667765969941434|[0.02900598446106...|      9|
# |   DEBIT|                       4|                            4|     -201.5700073|       115.1800003| Shipping on time|                 0|         17|              Cleats|           Caguas|     Puerto Rico|     XXXXXXXXX|          Mary|      10150|       Vasquez|        XXXXXXXXX|        Consumer|            PR|    3948 Tawny Crest|             725|            4|        Apparel|18.24462509|-66.37056732|  USCA|      New York City|Estados Unidos|            10150|    2016-04-10 04:25:00|   31868|                   365|        4.800000191|             0.039999999|        79641|             59.99000168|                  -1.75|                  2|119.9800034|     115.1800003|          -201.5700073|    East of USA|          Nueva York|       COMPLETE|        10024|            365|                 17|               NULL|http://images.acm...|Perfect Fitness P...|  59.99000168|             0|       2016-04-14 04:25:00|Standard Class|0.31842877861246677| -1.158384926150549|  0.3806699044248865|-0.8701003662517427|  0.313074713948174|[0.38066990442488...|      1|
# +--------+------------------------+-----------------------------+-----------------+------------------+-----------------+------------------+-----------+--------------------+-----------------+----------------+--------------+--------------+-----------+--------------+-----------------+----------------+--------------+--------------------+----------------+-------------+---------------+-----------+------------+------+-------------------+--------------+-----------------+-----------------------+--------+----------------------+-------------------+------------------------+-------------+------------------------+-----------------------+-------------------+-----------+----------------+----------------------+---------------+--------------------+---------------+-------------+---------------+-------------------+-------------------+--------------------+--------------------+-------------+--------------+--------------------------+--------------+-------------------+-------------------+--------------------+-------------------+-------------------+--------------------+-------+
# only showing top 20 rows

# %%
spark.stop()
